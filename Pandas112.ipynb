# %%
import numpy as np
import pandas as pd

# %%
draft1= pd.read_table('C:/Users/piyush/Downloads/code_pandas1/examples/ex1.csv', sep=',')
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(draft1)
# Out:
# pandas.core.frame.DataFrame

# %%
draft1.head(2)
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
draft1.tail(2)
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft2= pd.read_table(r'C:\Users\piyush\Downloads\code_pandas1\examples\test.tsv')
draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
draft2.head(1)
# Out:
#       test  test test.1 test.2 test.3
# sudh  sudh  sudh   sudh   sudh   sudh

# %%
draft2= pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\test.tsv',sep='\t')
draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex1.csv', header=None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex2.csv', names=['axx','bxx','cxx','dxc','aas','23','2323'])
df
# Out:
#    axx  bxx  cxx  dxc    aas  23  2323
# 0    1    2    3    4  hello NaN   NaN
# 1    5    6    7    8  world NaN   NaN
# 2    9   10   11   12    foo NaN   NaN

# %%
df=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\csv_mindex.csv', index_col=['key1','key2'])
df
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df2=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex4.csv', skiprows=[0,2,3])
df2
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
result=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex5.csv', na_values=['one','two',4])
result
# Out:
#   something  a   b     c     d message
# 0       NaN  1   2   3.0   NaN     NaN
# 1       NaN  5   6   NaN   8.0   world
# 2     three  9  10  11.0  12.0     foo

# %%
excel=pd.read_excel('path\filename.xlsx')
excel.head(()

# %%
excel=pd.read_excel('path\filename.xlsx' ,sheet_name= 'sheet3')

# %%
#url="https://finance.yahoo.com/quote/TSLA/profile?p=TSLA"

# %%
bb_data=pd.read_html("https://finance.yahoo.com/quote/TSLA/profile?p=TSLA")
bb_data

# %%
bb_data[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0f4cfbb64840> in <module>
# ----> 1 bb_data[0]
#
# NameError: name 'bb_data' is not defined

# %%
type(bb_data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
len(bb_data[0])
# Out:
# 5

# %%
bb_data[0]

# %%
bb_data[0].head(3)
# Out:
#                       Name                        Title      Pay Exercised  \
# 0         Mr. Elon R. Musk   Co-Founder, CEO & Director   23.76k       NaN
# 1  Mr. Zachary J. Kirkhorn      Chief Financial Officer  276.06k       NaN
# 2       Mr. Jerome Guillen  Pres of Automotive Division  301.15k     2.56M
#
#    Year Born
# 0       1972
# 1       1985
# 2       1973

# %%
bb_data[0].tail(10)

# %%
df=bb_data[0]
df.columns
# Out:
# Index(['Name', 'Title', 'Pay', 'Exercised', 'Year Born'], dtype='object')

# %%
df.dtypes
# Out:
# Name         object
# Title        object
# Pay          object
# Exercised    object
# Year Born     int64
# dtype: object

# %%
type(bb_data[0]['Name']['Pay'])
# Out:
# pandas.core.series.Series

# %%
result=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex6.csv')
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
result.to_json('D:\data\output6.json')

# %%
result=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex6.csv', nrows=10)
result
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# 5  1.817480  0.742273  0.419395 -2.251035   Q
# 6 -0.776764  0.935518 -0.332872 -1.875641   U
# 7 -0.913135  1.530624 -0.572657  0.477252   K
# 8  0.358480 -0.497572 -0.367016  0.507702   S
# 9 -1.740877 -1.160417 -1.637830  2.172201   G

# %%
chunk=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex6.csv', chunksize= 1000)
chunk

# %%
for i in chunk:
    print(i)
# Out:
#           one       two     three      four key
# 0    0.467976 -0.038649 -0.295344 -1.824726   L
# 1   -0.358893  1.404453  0.704965 -0.200638   B
# 2   -0.501840  0.659254 -0.421691 -0.057688   G
# 3    0.204886  1.074134  1.388361 -0.982404   R
# 4    0.354628 -0.133116  0.283763 -0.837063   Q
# ..        ...       ...       ...       ...  ..
# 995  2.311896 -0.417070 -1.409599 -0.515821   M
# 996 -0.479893 -0.650419  0.745152 -0.646038   H
# 997  0.523331  0.787112  0.486066  1.093156   D
# 998 -0.362559  0.598894 -1.843201  0.887292   W
# 999 -0.096376 -1.012999 -0.657431 -0.573315   K
#
# [1000 rows x 5 columns]
#            one       two     three      four key
# 1000  0.467976 -0.038649 -0.295344 -1.824726   T
# 1001 -0.358893  1.404453  0.704965 -0.200638   J
# 1002 -0.501840  0.659254 -0.421691 -0.057688   R
# 1003  0.204886  1.074134  1.388361 -0.982404   S
# 1004  0.354628 -0.133116  0.283763 -0.837063   B
# ...        ...       ...       ...       ...  ..
# ...

# %%
data=pd.read_csv(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df=data[['a','b','c','d']]
df
# Out:
#    a   b     c   d
# 0  1   2   3.0   4
# 1  5   6   NaN   8
# 2  9  10  11.0  12

# %%
df.to_csv('D:\data\output.csv')

# %%
df.to_csv('D:\data\output7.csv')

# %%
df.to_excel('D:\data2\output1.xlsx')

# %%
df.to_csv('D:\data2\output2.csv', sep='#')

# %%
df.to_csv('D:\data\output3.csv', index=False)

# %%
df.to_csv('D:\data\output4.csv',index=False, header=False)

# %%
df.to_csv('D:\data\output4.csv',index=False, header=False)

# %%
df.to_csv('D:\data\output5.csv',index=False, header=False, columns=['a'])

# %%
import csv
f= open(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex7.csv')
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\piyush\\Downloads\\code_pandas1\\examples\\ex7.csv' mode='r' encoding='cp1252'>

# %%
import csv
f= open(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex7.csv')
reader= (csv.reader(f))
reader

# %%
for  line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open(r'C:\Users\piyush\Downloads\code_pandas1\examples\ex7.csv')as f:
    lines=list(csv.reader(f))

# %%
lines
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %%
lines[0]
# Out:
# ['a', 'b', 'c']

# %%
lines[1]
# Out:
# ['1', '2', '3']

# %%
lines[2]
# Out:
# ['1', '2', '3']

# %%
lines[1:]
# Out:
# [['1', '2', '3'], ['1', '2', '3']]

# %%
header,values=lines[0],lines[1:]

# %%
header
# Out:
# ['a', 'b', 'c']

# %%
values
# Out:
# [['1', '2', '3'], ['1', '2', '3']]

# %%
for h in zip(header,values):
    print(h)
# Out:
# ('a', ['1', '2', '3'])
# ('b', ['1', '2', '3'])

# %%
for h in zip(values):
    print(h)
# Out:
# (['1', '2', '3'],)
# (['1', '2', '3'],)

# %%
for h in zip(*values):
    print(h)
# Out:
# ('1', '1')
# ('2', '2')
# ('3', '3')

# %%
for h in zip(header,zip(*values)):
    print(h)
# Out:
# ('a', ('1', '1'))
# ('b', ('2', '2'))
# ('c', ('3', '3'))

# %%
d={}
for h,v in zip(header,zip(*values)):
               d[h]=v

# %%
d
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
"""hggfhhgh
ghghfghh
hfhfhgh
hjgjh"""
# Out:
# 'hggfhhgh\nghghfghh\nhfhfhgh\nhjgjh'

# %%
obj="""
{"name":"Wes",
"plces_lived":["india","USA","Spain"],
"pet":null,
"siblings":[{"name":"Scott","age":32,"pets":["Zeus","Zuko"]},
             {"name":"katie","age":38,"pets":["sixes","catches","Cisco"]}]
}
"""

# %%
type(obj)
# Out:
# str

# %%
import json
result= json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'plces_lived': ['india', 'USA', 'Spain'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 32, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'katie', 'age': 38, 'pets': ['sixes', 'catches', 'Cisco']}]}

# %%
type(result)
# Out:
# dict

# %%
asjson= json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "plces_lived": ["india", "USA", "Spain"], "pet": null, "siblings": [{"name": "Scott", "age": 32, "pets": ["Zeus", "Zuko"]}, {"name": "katie", "age": 38, "pets": ["sixes", "catches", "Cisco"]}]}'

# %%
type(asjson)
# Out:
# str

# %%
result['siblings']
# Out:
# [{'name': 'Scott', 'age': 32, 'pets': ['Zeus', 'Zuko']},
#  {'name': 'katie', 'age': 38, 'pets': ['sixes', 'catches', 'Cisco']}]

# %%
pd.DataFrame(result['siblings'])
# Out:
#     name  age                     pets
# 0  Scott   32             [Zeus, Zuko]
# 1  katie   38  [sixes, catches, Cisco]

# %%
pd.DataFrame(result['siblings'], columns=['name','pets'])
# Out:
#     name                     pets
# 0  Scott             [Zeus, Zuko]
# 1  katie  [sixes, catches, Cisco]

# %%
pd.DataFrame(result['plces_lived'])
# Out:
#        0
# 0  india
# 1    USA
# 2  Spain

# %%
pd.DataFrame(result['name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-eb30885eb967> in <module>
# ----> 1 pd.DataFrame(result['name'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
data=pd.read_json(r"C:\Users\piyush\Downloads\code_pandas1\examples\example.json")

# %%
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
a=data.to_json()
a
# Out:
# '{"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}'

# %%
b=data.to_json(orient='records')
b
# Out:
# '[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]'

# %%
#xml and html w

# %%
tables=pd.read_html(r'C:/Users/piyush/Downloads/code_pandas1/examples/fdic_failed_bank_list.html')
tables
# Out:
# [                             Bank Name             City  ST   CERT  \
#  0                          Allied Bank         Mulberry  AR     91
#  1         The Woodbury Banking Company         Woodbury  GA  11297
#  2               First CornerStone Bank  King of Prussia  PA  35312
#  3                   Trust Company Bank          Memphis  TN   9956
#  4           North Milwaukee State Bank        Milwaukee  WI  20364
#  ..                                 ...              ...  ..    ...
#  542                 Superior Bank, FSB         Hinsdale  IL  32646
#  543                Malta National Bank            Malta  OH   6629
#  544    First Alliance Bank & Trust Co.       Manchester  NH  34264
#  545  National State Bank of Metropolis       Metropolis  IL   3815
#  546                   Bank of Honolulu         Honolulu  HI  21029
#
#                     Acquiring Institution        Closing Date  \
#  0                           Today's Bank  September 23, 2016
# ...

# %%
len(tables)
# Out:
# 1

# %%
type(tables)
# Out:
# list

# %%
a=tables[0]
a
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a['City']
# Out:
# 0             Mulberry
# 1             Woodbury
# 2      King of Prussia
# 3              Memphis
# 4            Milwaukee
#             ...
# 542           Hinsdale
# 543              Malta
# 544         Manchester
# 545         Metropolis
# 546           Honolulu
# Name: City, Length: 547, dtype: object

# %%
a['Closing Date']
# Out:
# 0      September 23, 2016
# 1         August 19, 2016
# 2             May 6, 2016
# 3          April 29, 2016
# 4          March 11, 2016
#               ...
# 542         July 27, 2001
# 543           May 3, 2001
# 544      February 2, 2001
# 545     December 14, 2000
# 546      October 13, 2000
# Name: Closing Date, Length: 547, dtype: object

# %%
type(a['CERT'])
# Out:
# pandas.core.series.Series

# %%
type(a['CERT'][0])
# Out:
# numpy.int64

# %%
a.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
a.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
time=pd.to_datetime(a['Closing Date'])
time
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
#          ...
# 542   2001-07-27
# 543   2001-05-03
# 544   2001-02-02
# 545   2000-12-14
# 546   2000-10-13
# Name: Closing Date, Length: 547, dtype: datetime64[ns]

# %%
time.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %%
time.dt.day.value_counts()
# Out:
# 23    31
# 30    30
# 19    30
# 20    27
# 17    23
# 16    22
# 4     21
# 18    21
# 7     20
# 15    20
# 2     20
# 14    20
# 24    19
# 28    18
# 27    18
# 22    18
# 11    18
# 21    17
# 29    16
# 26    15
# 5     15
# 13    14
# 10    14
# 8     14
# 6     14
# 25    13
# 12    10
# 9     10
# 31     8
# 1      8
# 3      3
# Name: Closing Date, dtype: int64

# %%
time.dt.month.value_counts()
# Out:
# 7     74
# 10    58
# 4     58
# 1     49
# 2     44
# 8     41
# 5     41
# 3     39
# 9     38
# 6     36
# 11    35
# 12    34
# Name: Closing Date, dtype: int64

# %%
time.dt.week.value_counts()
# Out:
# 17    25
# 29    20
# 30    20
# 44    19
# 3     18
# 4     18
# 33    18
# 15    16
# 42    16
# 50    16
# 7     15
# 27    15
# 28    14
# 16    13
# 45    13
# 37    12
# 6     11
# 5     11
# 10    11
# 43    11
# 12    11
# 31    11
# 18    11
# 9     11
# 21    10
# 19    10
# 36    10
# 41    10
# 46    10
# 51     9
# 25     9
# 49     9
# 26     9
# 40     9
# 23     8
# 38     8
# 11     8
# 20     7
# 22     7
# 39     7
# 34     7
# 35     6
# 8      6
# 32     6
# 24     6
# 2      6
# 14     4
# 47     4
# 13     3
# 1      3
# Name: Closing Date, dtype: int64

# %%
#binary data format

# %%
frame=pd.read_csv('C:/Users/piyush/Downloads/code_pandas1/examples/ex1.csv')
frame
frame.to_pickle('fmpickel')

# %%
pd.read_pickle('fmpickel')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import requests

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
resp=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/36325',
#   'id': 700511964,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg2MTM5ODgx',
#   'number': 36325,
#   'title': 'PERF: StringArray construction',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
# ...

# %%
data=resp.json()
data[2]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36323',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36323/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36323/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36323/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/36323',
#  'id': 700492472,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg2MTI0MTQy',
#  'number': 36323,
#  'title': 'CI: install numpy from pip #36296',
#  'user': {'login': 'VirosaLi',
#   'id': 7614606,
#   'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/VirosaLi',
#   'html_url': 'https://github.com/VirosaLi',
#   'followers_url': 'https://api.github.com/users/VirosaLi/followers',
# ...

# %%
len(data)
# Out:
# 30

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# dict

# %%
data[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36325/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/36325',
#  'id': 700511964,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NDg2MTM5ODgx',
#  'number': 36325,
#  'title': 'PERF: StringArray construction',
#  'user': {'login': 'topper-123',
#   'id': 26364415,
#   'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#   'avatar_url': 'https://avatars1.githubusercontent.com/u/26364415?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/topper-123',
#   'html_url': 'https://github.com/topper-123',
#   'followers_url': 'https://api.github.com/users/topper-123/followers',
# ...

# %%
data[0]['url']
# Out:
# 'https://api.github.com/repos/pandas-dev/pandas/issues/36325'

# %%
data[0]['title']
# Out:
# 'PERF: StringArray construction'

# %%
data[0]['user']['id']
# Out:
# 26364415

# %%
dff=pd.DataFrame(data)

# %%
dff
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
dff.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'pull_request', 'body',
#        'performed_via_github_app'],
#       dtype='object')
