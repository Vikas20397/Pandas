# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
min(titanic_train["Fare"])
# Out:
# 6.75

# %%
titanic_train.iloc[5:15:2]
# Out:
#     PassengerId  Survived  Pclass                                 Name  \
# 5             6         0       3                     Moran, Mr. James
# 7             8         0       3       Palsson, Master. Gosta Leonard
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 11           12         1       1             Bonnell, Miss. Elizabeth
# 13           14         0       3          Andersson, Mr. Anders Johan
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5     male   NaN      0      0  330877   8.4583   NaN        Q
# 7     male   2.0      3      1  349909  21.0750   NaN        S
# 9   female  14.0      1      0  237736  30.0708   NaN        C
# 11  female  58.0      0      0  113783  26.5500  C103        S
# 13    male  39.0      1      5  347082  31.2750   NaN        S

# %%
a=titanic_train["Fare"]==max(titanic_train["Fare"])
z=np.where(a)
z
titanic_train.iloc[[27,88]]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S

# %%
titanic_train[(titanic_train["Fare"]==6.75)]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 143          144         0       3  Burke, Mr. Jeremiah  male  19.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 143      0  365222  6.75   NaN        Q

# %%
titanic_train[(titanic_train["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 0              1         0       3          Braund, Mr. Owen Harris  male
# 4              5         0       3         Allen, Mr. William Henry  male
# 5              6         0       3                 Moran, Mr. James  male
# 6              7         0       1          McCarthy, Mr. Timothy J  male
# 7              8         0       3   Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                              ...   ...
# 150          151         0       2       Bateman, Rev. Robert James  male
# 152          153         0       3                 Meo, Mr. Alfonzo  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 154          155         0       3            Olsen, Mr. Ole Martin  male
# 155          156         0       1      Williams, Mr. Charles Duane  male
#
#       Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 0    22.0      1      0    A/5 21171   7.2500   NaN        S
# 4    35.0      0      0       373450   8.0500   NaN        S
# 5     NaN      0      0       330877   8.4583   NaN        Q
# 6    54.0      0      0        17463  51.8625   E46        S
# 7     2.0      3      1       349909  21.0750   NaN        S
# ..    ...    ...    ...          ...      ...   ...      ...
# 150  51.0      0      0  S.O.P. 1166  12.5250   NaN        S
# 152  55.5      0      0   A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2     A/5. 851  14.5000   NaN        S
# 154   NaN      0      0    Fa 265302   7.3125   NaN        S
# 155  51.0      0      1     PC 17597  61.3792   NaN        C
#
# [100 rows x 12 columns]

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train[["Name","Sex","Ticket","Cabin","Embarked"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 151            113776    C2        S
# 152        A.5. 11206   NaN        S
# 153          A/5. 851   NaN        S
# 154         Fa 265302   NaN        S
# 155          PC 17597   NaN        C
#
# [156 rows x 5 columns]

# %%
titanic_train[["Name","Sex","Ticket","Cabin","Embarked"]].describe()
# Out:
#                            Name   Sex   Ticket Cabin Embarked
# count                       156   156      156    31      155
# unique                      156     2      145    28        3
# top     Jussila, Miss. Katriina  male  CA 2144  C123        S
# freq                          1   100        2     2      110

# %%
titanic_train.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_train.dtypes[titanic_train.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(titanic_train.dtypes)
# Out:
# pandas.core.series.Series

# %%
titanic_train.dtypes[0]
# Out:
# dtype('int64')

# %%
titanic_train.dtypes["Name"]
# Out:
# dtype('O')

# %%
a=titanic_train.dtypes[titanic_train.dtypes=="object"].index
a
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[a]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 151            113776    C2        S
# 152        A.5. 11206   NaN        S
# 153          A/5. 851   NaN        S
# 154         Fa 265302   NaN        S
# 155          PC 17597   NaN        C
#
# [156 rows x 5 columns]

# %%
c=titanic_train.dtypes[titanic_train.dtypes=="int64"].index
c
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
titanic_train[c]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 151          152         1       1      1      0
# 152          153         0       3      0      0
# 153          154         0       3      0      2
# 154          155         0       3      0      0
# 155          156         0       1      0      1
#
# [156 rows x 5 columns]

# %%
b=titanic_train.dtypes[titanic_train.dtypes=="float64"].index
b
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
titanic_train[b]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 151  22.0  66.6000
# 152  55.5   8.0500
# 153  40.5  14.5000
# 154   NaN   7.3125
# 155  51.0  61.3792
#
# [156 rows x 2 columns]

# %%
titanic_train[a]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 151            113776    C2        S
# 152        A.5. 11206   NaN        S
# 153          A/5. 851   NaN        S
# 154         Fa 265302   NaN        S
# 155          PC 17597   NaN        C
#
# [156 rows x 5 columns]

# %%
type(titanic_train["Name"])
# Out:
# pandas.core.frame.DataFrame

# %%
s=titanic_train[["Name"]]
sorted(titanic_train["Name"])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
#  'Christmann, Mr. Emil',
#  'Chronopoulos, Mr. Apostolos',
#  'Coelho, Mr. Domingos Fernandeo',
#  'Connors, Mr. Patrick',
#  'Coxon, Mr. Daniel',
#  'Crease, Mr. Ernest James',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Dean, Mr. Bertram Frank',
#  'Devaney, Miss. Margaret Delia',
#  'Doling, Mrs. John T (Ada Julia Bone)',
#  'Dowdell, Miss. Elizabeth',
#  'Drazenoic, Mr. Jozef',
#  'Ekstrom, Mr. Johan',
#  'Emir, Mr. Farred Chehab',
#  'Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#  'Ford, Miss. Robina Maggie "Ruby"',
#  'Ford, Mr. William Neal',
#  'Fortune, Miss. Mabel Helen',
#  'Fortune, Mr. Charles Alexander',
#  'Futrelle, Mr. Jacques Heath',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Fynney, Mr. Joseph J',
#  'Giglio, Mr. Victor',
#  'Glynn, Miss. Mary Agatha',
#  'Goldschmidt, Mr. George B',
#  'Goodwin, Master. William Frederick',
#  'Goodwin, Miss. Lillian Amy',
#  'Greenfield, Mr. William Bertram',
#  'Gustafsson, Mr. Anders Vilhelm',
#  'Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)',
#  'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#  'Harris, Mr. Henry Birkhardt',
#  'Heikkinen, Miss. Laina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Hickman, Mr. Stanley George',
#  'Holverson, Mr. Alexander Oskar',
#  'Hood, Mr. Ambrose Jr',
#  'Icard, Miss. Amelie',
#  'Ilett, Miss. Bertha',
#  'Jenkin, Mr. Stephen Curnow',
#  'Johansson, Mr. Gustaf Joel',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Jussila, Miss. Katriina',
#  'Kantor, Mr. Sinai',
#  'Kink, Mr. Vincenz',
#  'Kraeff, Mr. Theodor',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Lennon, Mr. Denis',
#  'Madsen, Mr. Fridtjof Arne',
#  'Mamee, Mr. Hanna',
#  'Masselmani, Mrs. Fatima',
#  'McCarthy, Mr. Timothy J',
#  'McDermott, Miss. Brigdet Delia',
#  'McGowan, Miss. Anna "Annie"',
#  'McMahon, Mr. Martin',
#  'Meo, Mr. Alfonzo',
#  'Meyer, Mr. Edgar Joseph',
#  'Mionoff, Mr. Stoytcho',
#  'Moen, Mr. Sigurd Hansen',
#  'Moore, Mr. Leonard Charles',
#  'Moran, Miss. Bertha',
#  'Moran, Mr. James',
#  'Moss, Mr. Albert Johan',
#  'Moubarek, Master. Gerios',
#  'Moutal, Mr. Rahamin Haim',
#  'Nasser, Mr. Nicholas',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Navratil, Mr. Michel ("Louis M Hoffman")',
#  'Newsom, Miss. Helen Monypeny',
#  'Nicholls, Mr. Joseph Charles',
#  'Nicola-Yarred, Master. Elias',
#  'Nicola-Yarred, Miss. Jamila',
#  'Nosworthy, Mr. Richard Cater',
#  'Novel, Mr. Mansouer',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Nysten, Miss. Anna Sofia',
#  "O'Driscoll, Miss. Bridget",
#  'O\'Dwyer, Miss. Ellen "Nellie"',
#  'Olsen, Mr. Ole Martin',
#  'Osen, Mr. Olaf Elon',
#  'Ostby, Mr. Engelhart Cornelius',
#  'Palsson, Master. Gosta Leonard',
#  'Palsson, Miss. Torborg Danira',
#  'Panula, Master. Juha Niilo',
#  'Pears, Mrs. Thomas (Edith Wearne)',
#  'Pekoniemi, Mr. Edvard',
#  'Peter, Miss. Anna',
#  'Petranec, Miss. Matilda',
#  'Petroff, Mr. Pastcho ("Pentcho")',
#  'Porter, Mr. Walter Chamberlain',
#  'Rekic, Mr. Tido',
#  'Rice, Master. Eugene',
#  'Richard, Mr. Emile',
#  'Robins, Mrs. Alexander A (Grace Charity Laury)',
#  'Rogers, Mr. William John',
#  'Rugg, Miss. Emily',
#  'Salkjelsvik, Miss. Anna Kristine',
#  'Samaan, Mr. Youssef',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Saundercock, Mr. William Henry',
#  'Sheerlinck, Mr. Jan Baptist',
#  'Shorney, Mr. Charles Joseph',
#  'Sirayanian, Mr. Orsen',
#  'Skoog, Master. Harald',
#  'Slocovski, Mr. Selman Francis',
#  'Sloper, Mr. William Thompson',
#  'Sobey, Mr. Samuel James Hayden',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Staneff, Mr. Ivan',
#  'Stewart, Mr. Albert A',
#  'Todoroff, Mr. Lalio',
#  'Turpin, Mr. William John Robert',
#  'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  'Uruchurtu, Don. Manuel E',
#  'Vander Planke, Miss. Augusta Maria',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Waelens, Mr. Achille',
#  'Webber, Miss. Susan',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'West, Miss. Constance Mirium',
#  'Wheadon, Mr. Edward H',
#  'White, Mr. Percival Wayland',
#  'White, Mr. Richard Frasar',
#  'Williams, Mr. Charles Duane',
#  'Williams, Mr. Charles Eugene',
#  'Woolner, Mr. Hugh',
#  'Zabour, Miss. Hileni',
#  'van Billiard, Mr. Austin Blyler']

# %%
sorted(titanic_train["Age"])
# Out:
# [2.0,
#  2.0,
#  4.0,
#  8.0,
#  14.0,
#  14.0,
#  15.0,
#  18.0,
#  19.0,
#  20.0,
#  21.0,
#  22.0,
#  26.0,
#  27.0,
#  28.0,
#  28.0,
#  31.0,
#  34.0,
#  35.0,
#  35.0,
#  38.0,
#  nan,
#  35.0,
#  38.0,
#  39.0,
#  40.0,
#  42.0,
#  54.0,
#  55.0,
#  58.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  66.0,
#  nan,
#  3.0,
#  14.0,
#  19.0,
#  27.0,
#  40.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  4.0,
#  5.0,
#  7.0,
#  11.0,
#  16.0,
#  17.0,
#  18.0,
#  19.0,
#  21.0,
#  21.0,
#  21.0,
#  22.0,
#  25.0,
#  26.0,
#  26.0,
#  28.5,
#  29.0,
#  29.0,
#  32.0,
#  32.0,
#  38.0,
#  45.0,
#  49.0,
#  65.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  0.83,
#  16.0,
#  17.0,
#  17.0,
#  20.0,
#  21.0,
#  21.0,
#  22.0,
#  22.0,
#  23.0,
#  23.0,
#  24.0,
#  26.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  30.0,
#  nan,
#  33.0,
#  nan,
#  14.5,
#  20.0,
#  21.0,
#  29.0,
#  33.0,
#  34.0,
#  37.0,
#  38.0,
#  46.0,
#  59.0,
#  nan,
#  34.0,
#  47.0,
#  70.5,
#  71.0,
#  nan,
#  nan,
#  nan,
#  2.0,
#  9.0,
#  16.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  20.0,
#  21.0,
#  22.0,
#  22.0,
#  23.0,
#  24.0,
#  25.0,
#  29.0,
#  nan,
#  12.0,
#  24.0,
#  24.0,
#  24.0,
#  27.0,
#  29.0,
#  32.5,
#  32.5,
#  33.0,
#  37.0,
#  40.5,
#  45.0,
#  54.0,
#  nan,
#  nan,
#  36.5,
#  42.0,
#  47.0,
#  nan,
#  51.0,
#  51.0,
#  55.5,
#  nan]

# %%
a=s[0:5]
a
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
sorted(s[50:100:2])
# Out:
# ['Name']

# %%
s=titanic_train[["Name"]]
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)
# 152                                   Meo, Mr. Alfonzo
# 153                    van Billiard, Mr. Austin Blyler
# 154                              Olsen, Mr. Ole Martin
# 155                        Williams, Mr. Charles Duane
#
# [156 rows x 1 columns]

# %%
type(titanic_train["Ticket"])
# Out:
# pandas.core.series.Series

# %%
type(titanic_train[["Ticket"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd.DataFrame(titanic_train["Ticket"]))
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train[["Fare","Parch"]].describe()
# Out:
#              Fare       Parch
# count  156.000000  156.000000
# mean    28.109587    0.397436
# std     39.401047    0.870146
# min      6.750000    0.000000
# 25%      8.003150    0.000000
# 50%     14.454200    0.000000
# 75%     30.371850    0.000000
# max    263.000000    5.000000

# %%
sorted(titanic_train[["Survived","Pclass"]])
# Out:
# ['Pclass', 'Survived']

# %%
titanic_train[["Survived","Pclass","Name"]].sort_values
# Out:
# <bound method DataFrame.sort_values of      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
# [156 rows x 3 columns]>

# %%
a=titanic_train["Name"]
for i in a:
    if i[0]=="S":
        print(i)
# Out:
# Sandstrom, Miss. Marguerite Rut
# Saundercock, Mr. William Henry
# Sloper, Mr. William Thompson
# Spencer, Mrs. William Augustus (Marie Eugenie)
# Samaan, Mr. Youssef
# Sirayanian, Mr. Orsen
# Skoog, Master. Harald
# Stewart, Mr. Albert A
# Staneff, Mr. Ivan
# Sheerlinck, Mr. Jan Baptist
# Slocovski, Mr. Selman Francis
# Shorney, Mr. Charles Joseph
# Salkjelsvik, Miss. Anna Kristine
# Sobey, Mr. Samuel James Hayden

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
titanic_train["new"]=0
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new
# 0        0         A/5 21171   7.2500   NaN        S    0
# 1        0          PC 17599  71.2833   C85        C    0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0
# 3        0            113803  53.1000  C123        S    0
# 4        0            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 151      0            113776  66.6000    C2        S    0
# 152      0        A.5. 11206   8.0500   NaN        S    0
# 153      2          A/5. 851  14.5000   NaN        S    0
# 154      0         Fa 265302   7.3125   NaN        S    0
# 155      1          PC 17597  61.3792   NaN        C    0
#
# [156 rows x 13 columns]

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new
# 0      0         A/5 21171   7.2500   NaN        S    0
# 1      0          PC 17599  71.2833   C85        C    0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0
# 3      0            113803  53.1000  C123        S    0
# 4      0            373450   8.0500   NaN        S    0

# %%
titanic_train["Parch"]=1
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new
# 0        1         A/5 21171   7.2500   NaN        S    0
# 1        1          PC 17599  71.2833   C85        C    0
# 2        1  STON/O2. 3101282   7.9250   NaN        S    0
# 3        1            113803  53.1000  C123        S    0
# 4        1            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 151      1            113776  66.6000    C2        S    0
# 152      1        A.5. 11206   8.0500   NaN        S    0
# 153      1          A/5. 851  14.5000   NaN        S    0
# 154      1         Fa 265302   7.3125   NaN        S    0
# 155      1          PC 17597  61.3792   NaN        C    0
#
# [156 rows x 13 columns]

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new
# 0        1         A/5 21171   7.2500   NaN        S    0
# 1        1          PC 17599  71.2833   C85        C    0
# 2        1  STON/O2. 3101282   7.9250   NaN        S    0
# 3        1            113803  53.1000  C123        S    0
# 4        1            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 151      1            113776  66.6000    C2        S    0
# 152      1        A.5. 11206   8.0500   NaN        S    0
# 153      1          A/5. 851  14.5000   NaN        S    0
# 154      1         Fa 265302   7.3125   NaN        S    0
# 155      1          PC 17597  61.3792   NaN        C    0
#
# [156 rows x 13 columns]

# %%
a=titanic_train
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new
# 0        1         A/5 21171   7.2500   NaN        S    0
# 1        1          PC 17599  71.2833   C85        C    0
# 2        1  STON/O2. 3101282   7.9250   NaN        S    0
# 3        1            113803  53.1000  C123        S    0
# 4        1            373450   8.0500   NaN        S    0
# ..     ...               ...      ...   ...      ...  ...
# 151      1            113776  66.6000    C2        S    0
# 152      1        A.5. 11206   8.0500   NaN        S    0
# 153      1          A/5. 851  14.5000   NaN        S    0
# 154      1         Fa 265302   7.3125   NaN        S    0
# 155      1          PC 17597  61.3792   NaN        C    0
#
# [156 rows x 13 columns]

# %%
pd.Categorical(titanic_train["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(titanic_train["Name"])
# Out:
# [Braund, Mr. Owen Harris, Cumings, Mrs. John Bradley (Florence Briggs Th..., Heikkinen, Miss. Laina, Futrelle, Mrs. Jacques Heath (Lily May Peel), Allen, Mr. William Henry, ..., Pears, Mrs. Thomas (Edith Wearne), Meo, Mr. Alfonzo, van Billiard, Mr. Austin Blyler, Olsen, Mr. Ole Martin, Williams, Mr. Charles Duane]
# Length: 156
# Categories (156, object): [Ahlin, Mrs. Johan (Johanna Persdotter Larsson), Allen, Mr. William Henry, Andersson, Miss. Ellis Anna Maria, Andersson, Miss. Erna Alexandra, ..., Williams, Mr. Charles Eugene, Woolner, Mr. Hugh, Zabour, Miss. Hileni, van Billiard, Mr. Austin Blyler]

# %%
pd.Categorical(titanic_train["Cabin"])
# Out:
# [NaN, C85, NaN, C123, NaN, ..., C2, NaN, NaN, NaN, NaN]
# Length: 156
# Categories (28, object): [A5, A6, B28, B30, ..., F G73, F2, F33, G6]

# %%
titanic_train["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_train["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
type(titanic_train["Cabin"][0])
# Out:
# float

# %%
titanic_train["Pclass"].astype(str)
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: object

# %%
a=titanic_train["Cabin"].astype(str)

# %%
type(a[0])
# Out:
# str

# %%
for i in a:
    print(i[0])
# Out:
# n
# C
# n
# C
# n
# n
# E
# n
# n
# n
# G
# C
# n
# n
# n
# n
# n
# n
# n
# n
# n
# D
# n
# A
# n
# n
# n
# C
# n
# n
# n
# B
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# D
# n
# B
# C
# n
# n
# n
# n
# n
# B
# C
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# C
# n
# n
# n
# E
# n
# n
# n
# A
# D
# n
# n
# n
# n
# D
# n
# n
# n
# n
# n
# n
# n
# C
# n
# n
# n
# n
# n
# n
# n
# B
# n
# n
# n
# n
# E
# D
# n
# n
# n
# F
# n
# n
# n
# n
# n
# n
# n
# D
# C
# n
# B
# n
# n
# n
# n
# n
# n
# n
# n
# F
# n
# n
# C
# n
# n
# n
# n

# %%
[i[0:2] for i in a]
# Out:
# ['na',
#  'C8',
#  'na',
#  'C1',
#  'na',
#  'na',
#  'E4',
#  'na',
#  'na',
#  'na',
#  'G6',
#  'C1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D5',
#  'na',
#  'A6',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'B7',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D3',
#  'na',
#  'B3',
#  'C5',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'B2',
#  'C8',
#  'na',
#  'na',
#  'na',
#  'F3',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'F ',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'E3',
#  'na',
#  'na',
#  'na',
#  'A5',
#  'D1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D2',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'B5',
#  'na',
#  'na',
#  'na',
#  'na',
#  'E1',
#  'D2',
#  'na',
#  'na',
#  'na',
#  'F ',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D4',
#  'C1',
#  'na',
#  'B8',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'F2',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'na']

# %%
[i[0:2] for i in a]
# Out:
# ['na',
#  'C8',
#  'na',
#  'C1',
#  'na',
#  'na',
#  'E4',
#  'na',
#  'na',
#  'na',
#  'G6',
#  'C1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D5',
#  'na',
#  'A6',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'B7',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D3',
#  'na',
#  'B3',
#  'C5',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'B2',
#  'C8',
#  'na',
#  'na',
#  'na',
#  'F3',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'F ',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'E3',
#  'na',
#  'na',
#  'na',
#  'A5',
#  'D1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D2',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'C1',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'B5',
#  'na',
#  'na',
#  'na',
#  'na',
#  'E1',
#  'D2',
#  'na',
#  'na',
#  'na',
#  'F ',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'D4',
#  'C1',
#  'na',
#  'B8',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'na',
#  'F2',
#  'na',
#  'na',
#  'C2',
#  'na',
#  'na',
#  'na',
#  'na']

# %%
[i[0:2] for i in titanic_train["Name"]]
# Out:
# ['Br',
#  'Cu',
#  'He',
#  'Fu',
#  'Al',
#  'Mo',
#  'Mc',
#  'Pa',
#  'Jo',
#  'Na',
#  'Sa',
#  'Bo',
#  'Sa',
#  'An',
#  'Ve',
#  'He',
#  'Ri',
#  'Wi',
#  'Va',
#  'Ma',
#  'Fy',
#  'Be',
#  'Mc',
#  'Sl',
#  'Pa',
#  'As',
#  'Em',
#  'Fo',
#  "O'",
#  'To',
#  'Ur',
#  'Sp',
#  'Gl',
#  'Wh',
#  'Me',
#  'Ho',
#  'Ma',
#  'Ca',
#  'Va',
#  'Ni',
#  'Ah',
#  'Tu',
#  'Kr',
#  'La',
#  'De',
#  'Ro',
#  'Le',
#  "O'",
#  'Sa',
#  'Ar',
#  'Pa',
#  'No',
#  'Ha',
#  'Fa',
#  'Os',
#  'Wo',
#  'Ru',
#  'No',
#  'We',
#  'Go',
#  'Si',
#  'Ic',
#  'Ha',
#  'Sk',
#  'St',
#  'Mo',
#  'Ny',
#  'Cr',
#  'An',
#  'Ki',
#  'Je',
#  'Go',
#  'Ho',
#  'Ch',
#  'Bi',
#  'Mo',
#  'St',
#  'Mo',
#  'Ca',
#  'Do',
#  'Wa',
#  'Sh',
#  'Mc',
#  'Ca',
#  'Il',
#  'Ba',
#  'Fo',
#  'Sl',
#  'Fo',
#  'Ce',
#  'Ch',
#  'An',
#  'Ch',
#  'De',
#  'Co',
#  'Sh',
#  'Go',
#  'Gr',
#  'Do',
#  'Ka',
#  'Pe',
#  'Pe',
#  'Wh',
#  'Jo',
#  'Gu',
#  'Mi',
#  'Sa',
#  'Mo',
#  'Re',
#  'Mo',
#  'Po',
#  'Za',
#  'Ba',
#  'Ju',
#  'At',
#  'Pe',
#  'Co',
#  'Tu',
#  'Ba',
#  'An',
#  'Hi',
#  'Mo',
#  'Na',
#  'We',
#  'Wh',
#  'Ni',
#  'Mc',
#  'Ma',
#  'Pe',
#  'Ek',
#  'Dr',
#  'Co',
#  'Ro',
#  'We',
#  'So',
#  'Ri',
#  'Ne',
#  'Fu',
#  'Os',
#  'Gi',
#  'Bo',
#  'Ny',
#  'Ha',
#  'Bu',
#  'An',
#  'Ni',
#  'An',
#  'Fo',
#  'Na',
#  'By',
#  'Ba',
#  'Pe',
#  'Me',
#  'va',
#  'Ol',
#  'Wi']

# %%
l=[]
for i in titanic_train["Name"]:
    l.append(i[0:2])
l
# Out:
# ['Br',
#  'Cu',
#  'He',
#  'Fu',
#  'Al',
#  'Mo',
#  'Mc',
#  'Pa',
#  'Jo',
#  'Na',
#  'Sa',
#  'Bo',
#  'Sa',
#  'An',
#  'Ve',
#  'He',
#  'Ri',
#  'Wi',
#  'Va',
#  'Ma',
#  'Fy',
#  'Be',
#  'Mc',
#  'Sl',
#  'Pa',
#  'As',
#  'Em',
#  'Fo',
#  "O'",
#  'To',
#  'Ur',
#  'Sp',
#  'Gl',
#  'Wh',
#  'Me',
#  'Ho',
#  'Ma',
#  'Ca',
#  'Va',
#  'Ni',
#  'Ah',
#  'Tu',
#  'Kr',
#  'La',
#  'De',
#  'Ro',
#  'Le',
#  "O'",
#  'Sa',
#  'Ar',
#  'Pa',
#  'No',
#  'Ha',
#  'Fa',
#  'Os',
#  'Wo',
#  'Ru',
#  'No',
#  'We',
#  'Go',
#  'Si',
#  'Ic',
#  'Ha',
#  'Sk',
#  'St',
#  'Mo',
#  'Ny',
#  'Cr',
#  'An',
#  'Ki',
#  'Je',
#  'Go',
#  'Ho',
#  'Ch',
#  'Bi',
#  'Mo',
#  'St',
#  'Mo',
#  'Ca',
#  'Do',
#  'Wa',
#  'Sh',
#  'Mc',
#  'Ca',
#  'Il',
#  'Ba',
#  'Fo',
#  'Sl',
#  'Fo',
#  'Ce',
#  'Ch',
#  'An',
#  'Ch',
#  'De',
#  'Co',
#  'Sh',
#  'Go',
#  'Gr',
#  'Do',
#  'Ka',
#  'Pe',
#  'Pe',
#  'Wh',
#  'Jo',
#  'Gu',
#  'Mi',
#  'Sa',
#  'Mo',
#  'Re',
#  'Mo',
#  'Po',
#  'Za',
#  'Ba',
#  'Ju',
#  'At',
#  'Pe',
#  'Co',
#  'Tu',
#  'Ba',
#  'An',
#  'Hi',
#  'Mo',
#  'Na',
#  'We',
#  'Wh',
#  'Ni',
#  'Mc',
#  'Ma',
#  'Pe',
#  'Ek',
#  'Dr',
#  'Co',
#  'Ro',
#  'We',
#  'So',
#  'Ri',
#  'Ne',
#  'Fu',
#  'Os',
#  'Gi',
#  'Bo',
#  'Ny',
#  'Ha',
#  'Bu',
#  'An',
#  'Ni',
#  'An',
#  'Fo',
#  'Na',
#  'By',
#  'Ba',
#  'Pe',
#  'Me',
#  'va',
#  'Ol',
#  'Wi']

# %%
pd.Series([i[0] for i in titanic_train["Name"]]).unique()
# Out:
# array(['B', 'C', 'H', 'F', 'A', 'M', 'P', 'J', 'N', 'S', 'V', 'R', 'W',
#        'E', 'O', 'T', 'U', 'G', 'K', 'L', 'D', 'I', 'Z', 'v'],
#       dtype=object)

# %%
 titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
 titanic_train["Age"].isnull()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
 index_val=np.where(titanic_train["Age"].isnull()==True)
 index_val
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
titanic_train.iloc[ index_val]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 128          129         1       3
# 140          141         0       3
# 154          155         0       3
#
#                                                Name     Sex  Age  SibSp  \
# 5                                  Moran, Mr. James    male  NaN      0
# 17                     Williams, Mr. Charles Eugene    male  NaN      0
# 19                          Masselmani, Mrs. Fatima  female  NaN      0
# 26                          Emir, Mr. Farred Chehab    male  NaN      0
# 28                    O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                              Todoroff, Mr. Lalio    male  NaN      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1
# 32                         Glynn, Miss. Mary Agatha  female  NaN      0
# 36                                 Mamee, Mr. Hanna    male  NaN      0
# 42                              Kraeff, Mr. Theodor    male  NaN      0
# 45                         Rogers, Mr. William John    male  NaN      0
# 46                                Lennon, Mr. Denis    male  NaN      1
# 47                        O'Driscoll, Miss. Bridget  female  NaN      0
# 48                              Samaan, Mr. Youssef    male  NaN      2
# 55                                Woolner, Mr. Hugh    male  NaN      0
# 64                            Stewart, Mr. Albert A    male  NaN      0
# 65                         Moubarek, Master. Gerios    male  NaN      1
# 76                                Staneff, Mr. Ivan    male  NaN      0
# 77                         Moutal, Mr. Rahamin Haim    male  NaN      0
# 82                   McDermott, Miss. Brigdet Delia  female  NaN      0
# 87                    Slocovski, Mr. Selman Francis    male  NaN      0
# 95                      Shorney, Mr. Charles Joseph    male  NaN      0
# 101                Petroff, Mr. Pastcho ("Pentcho")    male  NaN      0
# 107                          Moss, Mr. Albert Johan    male  NaN      0
# 109                             Moran, Miss. Bertha  female  NaN      1
# 121                      Moore, Mr. Leonard Charles    male  NaN      0
# 126                             McMahon, Mr. Martin    male  NaN      0
# 128                               Peter, Miss. Anna  female  NaN      1
# 140                   Boulos, Mrs. Joseph (Sultana)  female  NaN      0
# 154                           Olsen, Mr. Ole Martin    male  NaN      0
#
#      Parch           Ticket      Fare  Cabin Embarked  new
# 5        0           330877    8.4583    NaN        Q    0
# 17       0           244373   13.0000    NaN        S    0
# 19       0             2649    7.2250    NaN        C    0
# 26       0             2631    7.2250    NaN        C    0
# 28       0           330959    7.8792    NaN        Q    0
# 29       0           349216    7.8958    NaN        S    0
# 31       0         PC 17569  146.5208    B78        C    0
# 32       0           335677    7.7500    NaN        Q    0
# 36       0             2677    7.2292    NaN        C    0
# 42       0           349253    7.8958    NaN        C    0
# 45       0  S.C./A.4. 23567    8.0500    NaN        S    0
# 46       0           370371   15.5000    NaN        Q    0
# 47       0            14311    7.7500    NaN        Q    0
# 48       0             2662   21.6792    NaN        C    0
# 55       0            19947   35.5000    C52        S    0
# 64       0         PC 17605   27.7208    NaN        C    0
# 65       1             2661   15.2458    NaN        C    0
# 76       0           349208    7.8958    NaN        S    0
# 77       0           374746    8.0500    NaN        S    0
# 82       0           330932    7.7875    NaN        Q    0
# 87       0  SOTON/OQ 392086    8.0500    NaN        S    0
# 95       0           374910    8.0500    NaN        S    0
# 101      0           349215    7.8958    NaN        S    0
# 107      0           312991    7.7750    NaN        S    0
# 109      0           371110   24.1500    NaN        Q    0
# 121      0        A4. 54510    8.0500    NaN        S    0
# 126      0           370372    7.7500    NaN        Q    0
# 128      1             2668   22.3583  F E69        C    0
# 140      2             2678   15.2458    NaN        C    0
# 154      0        Fa 265302    7.3125    NaN        S    0

# %%
titani_train.iloc[]

# %%
titanic_train["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 151    66.6000
# 152     8.0500
# 153    14.5000
# 154     7.3125
# 155    61.3792
# Name: Fare, Length: 156, dtype: float64

# %%
max(titanic_train["Fare"])
# Out:
# 263.0

# %%
max_val=titanic_train["Fare"]==max(titanic_train["Fare"])
max_val
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
inmax_val=np.where(max_val)
inmax_val
# Out:
# (array([27, 88], dtype=int64),)

# %%
titanic_train.iloc[inmax_val]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S

# %%
titanic_train.iloc[inmax_val][["Name","Sex","Age"]]
# Out:
#                               Name     Sex   Age
# 27  Fortune, Mr. Charles Alexander    male  19.0
# 88      Fortune, Miss. Mabel Helen  female  23.0

# %%
min_val=titanic_train["Fare"]==min(titanic_train["Fare"])
min_val
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
inmin_val=np.where(min_val)
inmin_val
# Out:
# (array([143], dtype=int64),)

# %%
titanic_train.iloc[inmin_val][["Name","Sex","Age"]]
# Out:
#                     Name   Sex   Age
# 143  Burke, Mr. Jeremiah  male  19.0

# %%
titanic_train["PassengerId"]+titanic_train["Survived"]
# Out:
# 0        1
# 1        3
# 2        4
# 3        5
# 4        5
#       ...
# 151    153
# 152    153
# 153    154
# 154    155
# 155    156
# Length: 156, dtype: int64

# %%
titanic_train['new_comb']=titanic_train["PassengerId"]+titanic_train["Survived"]
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  new_comb
# 0        0         A/5 21171   7.2500   NaN        S         1
# 1        0          PC 17599  71.2833   C85        C         3
# 2        0  STON/O2. 3101282   7.9250   NaN        S         4
# 3        0            113803  53.1000  C123        S         5
# 4        0            373450   8.0500   NaN        S         5
# ..     ...               ...      ...   ...      ...       ...
# 151      0            113776  66.6000    C2        S       153
# 152      0        A.5. 11206   8.0500   NaN        S       153
# 153      2          A/5. 851  14.5000   NaN        S       154
# 154      0         Fa 265302   7.3125   NaN        S       155
# 155      1          PC 17597  61.3792   NaN        C       156
#
# [156 rows x 13 columns]

# %%
max(titanic_train["Age"])
# Out:
# 71.0

# %%
min(titanic_train["Age"])
# Out:
# 0.83

# %%
titanic_train["Age"].iloc[78]
# Out:
# 0.83

# %%
ag=np.where(titanic_train["Age"]==min(titanic_train["Age"]))

# %%
titanic_train.iloc[ag]
# Out:
#     PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 78           79         1       2  Caldwell, Master. Alden Gates  male  0.83
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 78      0      2  248738  29.0   NaN        S

# %%
com2=np.where(titanic_train["Fare"]==min(titanic_train["Fare"]))

# %%
titanic_train.iloc[com2]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 143          144         0       3  Burke, Mr. Jeremiah  male  19.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 143      0  365222  6.75   NaN        Q

# %%
labels=["a","b","c"]
my_data=[1,2,3]
arr=np.array(my_data)
dict={"a":10,"b":20,"c":30}

# %%
pd.Series(my_data)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
my_data[0:2]
# Out:
# [1, 2]

# %%
w=pd.Series(my_data, index=labels)
w
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
w["a"]
# Out:
# 1

# %%
s=pd.Series(my_data, index=["a","g","z"])
s[2]
# Out:
# 3

# %%
s['z']
# Out:
# 3

# %%
pd.Series(my_data, index=["1","@","z"])
# Out:
# 1    1
# @    2
# z    3
# dtype: int64

# %%
pd.Series(my_data, index=["1","@","z","4"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-4e975308f83a> in <module>
# ----> 1 pd.Series(my_data, index=["1","@","z","4"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     289                 try:
#     290                     if len(index) != len(data):
# --> 291                         raise ValueError(
#     292                             f"Length of passed values is {len(data)}, "
#     293                             f"index implies {len(index)}."
#
# ValueError: Length of passed values is 3, index implies 4.

# %%
d=pd.Series(my_data, index=["1","@","z"])
d[2]
# Out:
# 3

# %%
d=pd.Series(my_data, index=['11','12','13'])
d[1]
# Out:
# 2

# %%
d["@"]
# Out:
# 2

# %%
e=pd.Series(arr,index=labels)
e
# Out:
# a    1
# b    2
# c    3
# dtype: int32

# %%
e["a"]
# Out:
# 1

# %%
e[0]
# Out:
# 1

# %%
f=pd.Series(dict)
f
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
f[0]
# Out:
# 10

# %%
f["a"]
# Out:
# 10

# %%
g=pd.Series(dict, index=["1","z","c"])
g
# Out:
# 1     NaN
# z     NaN
# c    30.0
# dtype: float64

# %%
ser1=pd.Series([1,2,3,4],index=[5,6,7,8])
ser2=pd.Series([1,2,3,4],index=["5","6","7","8"])

# %%
ser1
# Out:
# 5    1
# 6    2
# 7    3
# 8    4
# dtype: int64

# %%
ser2
# Out:
# 5    1
# 6    2
# 7    3
# 8    4
# dtype: int64

# %%
ser2[0]
# Out:
# 1

# %%
ser2["5"]
# Out:
# 1

# %%
ser1[5]
# Out:
# 1

# %%
ser1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-11ab45b3fab4> in <module>
# ----> 1 ser1[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
ser1[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-71bd6e38c038> in <module>
# ----> 1 ser1[1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
ser1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-11ab45b3fab4> in <module>
# ----> 1 ser1[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
ser3=pd.Series([1,2,3,4],index=["aa","bb","cc","dd"])
ser4=pd.Series([1,2,3,4],index=["aa","zz","ww","cc"])
ser5=ser3+ser4
ser5
# Out:
# aa    2.0
# bb    NaN
# cc    7.0
# dd    NaN
# ww    NaN
# zz    NaN
# dtype: float64

# %%
ser6=ser3*ser4
ser6
# Out:
# aa     1.0
# bb     NaN
# cc    12.0
# dd     NaN
# qq     NaN
# zz     NaN
# dtype: float64

# %%
from numpy.random import randn as rn

# %%
y=rn(4,3)
y
# Out:
# array([[ 0.78657097,  1.26907021, -0.42341056],
#        [ 1.25175909,  0.21756058,  0.72280602],
#        [ 2.01691255,  0.46806495, -0.65796462],
#        [ 0.10415911,  0.25414972,  0.41877461]])

# %%
dataf0=pd.DataFrame(y)

# %%
dataf0.iloc[0]
# Out:
# 0    1.159807
# 1    0.993581
# 2   -1.380305
# Name: 0, dtype: float64

# %%
dataf0.loc[0]
# Out:
# 0    1.159807
# 1    0.993581
# 2   -1.380305
# Name: 0, dtype: float64

# %%
dataf0
# Out:
#           0         1         2
# 0  1.159807  0.993581 -1.380305
# 1 -0.551383 -0.350039 -2.360422
# 2 -0.799734  2.060549  1.279781
# 3  0.907851 -1.950160  0.231298

# %%
dataf1=pd.DataFrame(y,index=[1,2,3,4],columns=[5,6,7])
dataf1
# Out:
#           5         6         7
# 1  0.526773  0.960569  0.238437
# 2 -2.221955  0.319928 -0.673760
# 3 -1.296575 -1.880972  1.198062
# 4 -0.082209  0.279747  0.277744

# %%
dataf4=pd.DataFrame(y,index=["a","b","c","d"],columns=[5,6,7])
dataf4
# Out:
#           5         6         7
# a  0.786571  1.269070 -0.423411
# b  1.251759  0.217561  0.722806
# c  2.016913  0.468065 -0.657965
# d  0.104159  0.254150  0.418775

# %%
dataf4.loc[[0,1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-2cad976f7c3a> in <module>
# ----> 1 dataf4.loc[[0,1]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Int64Index([0, 1], dtype='int64')] are in the [index]"

# %%
dataf4.loc[["a","b"]]
# Out:
#           5         6         7
# a  0.786571  1.269070 -0.423411
# b  1.251759  0.217561  0.722806

# %%
dataf4.loc["a"]
# Out:
# 5    0.786571
# 6    1.269070
# 7   -0.423411
# Name: a, dtype: float64

# %%
dataf4.iloc["a"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-aeb2589b4852> in <module>
# ----> 1 dataf4.iloc["a"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2133             key = item_from_zerodim(key)
#    2134             if not is_integer(key):
# -> 2135                 raise TypeError("Cannot index by location index with a non-integer key")
#    2136
#    2137             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
dataf4
# Out:
#           5         6         7
# a  0.786571  1.269070 -0.423411
# b  1.251759  0.217561  0.722806
# c  2.016913  0.468065 -0.657965
# d  0.104159  0.254150  0.418775

# %%
dataf0
# Out:
#           0         1         2
# 0  1.159807  0.993581 -1.380305
# 1 -0.551383 -0.350039 -2.360422
# 2 -0.799734  2.060549  1.279781
# 3  0.907851 -1.950160  0.231298

# %%
dataf4["new_col"]=dataf4[5]+dataf4[6]
dataf4
# Out:
#           5         6         7   new_col
# a  0.786571  1.269070 -0.423411  2.055641
# b  1.251759  0.217561  0.722806  1.469320
# c  2.016913  0.468065 -0.657965  2.484978
# d  0.104159  0.254150  0.418775  0.358309

# %%
dataf0
# Out:
#           0         1         2
# 0  1.159807  0.993581 -1.380305
# 1 -0.551383 -0.350039 -2.360422
# 2 -0.799734  2.060549  1.279781
# 3  0.907851 -1.950160  0.231298

# %%
dataf4[[5,6]]
# Out:
#           5         6
# a  0.786571  1.269070
# b  1.251759  0.217561
# c  2.016913  0.468065
# d  0.104159  0.254150

# %%
dataf4
# Out:
#           5         6         7   new_col
# a  0.786571  1.269070 -0.423411  2.055641
# b  1.251759  0.217561  0.722806  1.469320
# c  2.016913  0.468065 -0.657965  2.484978
# d  0.104159  0.254150  0.418775  0.358309

# %%
dataf4.drop(5, axis=1)
# Out:
#           6         7   new_col
# a  1.269070 -0.423411  2.055641
# b  0.217561  0.722806  1.469320
# c  0.468065 -0.657965  2.484978
# d  0.254150  0.418775  0.358309

# %%
dataf4
# Out:
#           5         6         7   new_col
# a  0.786571  1.269070 -0.423411  2.055641
# b  1.251759  0.217561  0.722806  1.469320
# c  2.016913  0.468065 -0.657965  2.484978
# d  0.104159  0.254150  0.418775  0.358309

# %%
dataf4.drop("a")
# Out:
#           5         6         7   new_col
# b  1.251759  0.217561  0.722806  1.469320
# c  2.016913  0.468065 -0.657965  2.484978
# d  0.104159  0.254150  0.418775  0.358309

# %%
dataf4
# Out:
#           5         6         7   new_col
# a  0.786571  1.269070 -0.423411  2.055641
# b  1.251759  0.217561  0.722806  1.469320
# c  2.016913  0.468065 -0.657965  2.484978
# d  0.104159  0.254150  0.418775  0.358309

# %%
dataf4.drop(6, axis=1,inplace=True)
dataf4
# Out:
#           7   new_col
# a -0.423411  2.055641
# b  0.722806  1.469320
# c -0.657965  2.484978
# d  0.418775  0.358309

# %%
dataf4
# Out:
#           7   new_col
# a -0.423411  2.055641
# b  0.722806  1.469320
# c -0.657965  2.484978
# d  0.418775  0.358309

# %%
dataf4
# Out:
#           7   new_col
# a -0.423411  2.055641
# b  0.722806  1.469320
# c -0.657965  2.484978
# d  0.418775  0.358309

# %%
dataf4
# Out:
#           7   new_col
# a -0.423411  2.055641
# b  0.722806  1.469320
# c -0.657965  2.484978
# d  0.418775  0.358309

# %%
dataf3=dataf4.drop("c")
dataf4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-c51e3fb342ee> in <module>
#       1 dataf3=dataf4.drop("c")
# ----> 2 data4
#
# NameError: name 'data4' is not defined

# %%
dataf4=dataf4.drop("d")

# %%
dataf4
# Out:
#     new_col
# b  1.469320
# c  2.484978

# %%
dataf5=pd.DataFrame(y)
dataf5
# Out:
#           0         1         2
# 0  0.786571  1.269070 -0.423411
# 1  1.251759  0.217561  0.722806
# 2  2.016913  0.468065 -0.657965
# 3  0.104159  0.254150  0.418775

# %%
dataf5.iloc[[1,2]]
# Out:
#           0         1         2
# 1  1.251759  0.217561  0.722806
# 2  2.016913  0.468065 -0.657965

# %%
dataf5.iloc[[0,1],[0,1]]
# Out:
#           0         1
# 0  0.786571  1.269070
# 1  1.251759  0.217561

# %%
dataf5.iloc[[2,3],[1,2]]
# Out:
#           1         2
# 2 -1.880972  1.198062
# 3  0.279747  0.277744

# %%
dataf5.iloc[[1,3],[0,2]]
# Out:
#           0         2
# 1 -2.221955 -0.673760
# 3 -0.082209  0.277744

# %%
dataf5
# Out:
#           0         1         2
# 0  0.786571  1.269070 -0.423411
# 1  1.251759  0.217561  0.722806
# 2  2.016913  0.468065 -0.657965
# 3  0.104159  0.254150  0.418775

# %%
dataf5.iloc[:,[0]]
# Out:
#           0
# 0  0.786571
# 1  1.251759
# 2  2.016913
# 3  0.104159

# %%
dataf5.iloc[0:3:2,[1,2]]
# Out:
#           1         2
# 0  1.269070 -0.423411
# 2  0.468065 -0.657965

# %%
dataf5.iloc[[1,2],[1,2]]
# Out:
#           1         2
# 1  0.217561  0.722806
# 2  0.468065 -0.657965

# %%
dataf5
# Out:
#           0         1         2
# 0  0.786571  1.269070 -0.423411
# 1  1.251759  0.217561  0.722806
# 2  2.016913  0.468065 -0.657965
# 3  0.104159  0.254150  0.418775

# %%
dataf5[dataf5>1]
# Out:
#           0        1   2
# 0       NaN  1.26907 NaN
# 1  1.251759      NaN NaN
# 2  2.016913      NaN NaN
# 3       NaN      NaN NaN

# %%
dataf5>1
# Out:
#        0      1      2
# 0  False   True  False
# 1   True  False  False
# 2   True  False  False
# 3  False  False  False

# %%
dataf5[dataf5>0]
# Out:
#           0         1         2
# 0  0.786571  1.269070       NaN
# 1  1.251759  0.217561  0.722806
# 2  2.016913  0.468065       NaN
# 3  0.104159  0.254150  0.418775

# %%
dataf5[dataf5.iloc[[0,1]]>0]
# Out:
#           0         1         2
# 0  0.786571  1.269070       NaN
# 1  1.251759  0.217561  0.722806
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
